# %%
using JuMP
using Cbc
using GLPK
using ECOS
using HiGHS
using MAT
using SparseArrays
using DelimitedFiles
using LinearAlgebra
using MathOptInterface

# %%
# get inputs
vars = matread("R3T3.mat")
S = vars["S"]
U = vars["U"]
L = vars["L"]
# Out:
# 13094×50 SparseMatrixCSC{Float64, Int64} with 42839 stored entries:
# ⣿
# ⣿
# ⣿
# ⣿
# ⣿
# ⣿
# ⣿
# ⣿
# ⣿
# ⣿
# ⣿
# ⣿
# ⣿
# ⣿
# ⣿
# ⣿
# ⣿
# ⣿
# ⣿
# ⣿
# ⣿
# ⣿
# ⣿
# ⣿
# ⣿
# ⣿

# %%
# first use l1 as a estimation of l0 

size_of_v_r = 13094
size_of_v_c = 50

# define the problem
model = JuMP.Model(Cbc.Optimizer)

@variable(model, v[1:size_of_v_r, 1:size_of_v_c])  # define variable v
@variable(model, v_norm[1:size_of_v_r])
println("variables declared")
for i in 1:size_of_v_r
    for j in 1:size_of_v_c
        @constraint(model, v_norm[i] >= v[i,j])
        @constraint(model, v_norm[i] >= -v[i,j])
    end
end
println("v_norm constraints declared")
@constraint(model, Matrix(L) .<= v .<= Matrix(U))  # l1 <= v <= u1
@constraint(model, Matrix(S) * v .== 0)  # Sv = 0
println("main constraints declared")
@objective(model, Min, sum(v_norm[i] for i in 1:size_of_v_r))  # min ||v||_1
print("model created")
# Out:
# variables declared
# v_norm constraints declared
# main constraints declared
# model created

# %%
model
# Out:
# A JuMP Model
# Minimization problem with:
# Variables: 667794
# Objective function type: AffExpr
# `AffExpr`-in-`MathOptInterface.EqualTo{Float64}`: 420200 constraints
# `AffExpr`-in-`MathOptInterface.GreaterThan{Float64}`: 1309400 constraints
# `AffExpr`-in-`MathOptInterface.Interval{Float64}`: 654700 constraints
# Model mode: AUTOMATIC
# CachingOptimizer state: EMPTY_OPTIMIZER
# Solver name: COIN Branch-and-Cut (Cbc)
# Names registered in the model: v, v_norm

# %%
# solve the problem, see the status of it, and store the results
optimize!(model)
println(termination_status(model))
print(primal_status(model))
starting_v_norm = JuMP.value.(v_norm)
starting_v = JuMP.value.(v)
sparse(starting_v)
# Out:
# Presolve 9210 (-2375090) rows, 7228 (-660566) columns and 40484 (-6029666) elements
# 0  Obj 51.942401 Primal inf 3416.6874 (5863) Dual inf 5.5857e+13 (2641)
# 317  Obj 51.942401 Primal inf 3179.0566 (5628) Dual inf 5.6024683e+13 (2470)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2395)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2394)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2393)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2392)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2391)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2390)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2389)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2388)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2387)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2386)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2385)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2384)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2383)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2382)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2381)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2380)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2379)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2378)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2377)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2376)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2375)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2374)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2373)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2372)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2371)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2370)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2369)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2368)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2367)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2366)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2365)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2364)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2363)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2362)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2361)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2360)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2359)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2358)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2357)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2356)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2355)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2354)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2353)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2352)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2351)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2350)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2349)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2348)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2347)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2346)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2345)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2344)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2343)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2342)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2341)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2340)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2339)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2338)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2337)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2336)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2335)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2334)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2333)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2332)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2331)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2330)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2329)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2328)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2327)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2326)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2325)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2324)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2323)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2322)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2321)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2320)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2319)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2318)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2317)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2316)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2315)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2314)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2313)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2312)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2311)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2310)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2309)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2308)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2307)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2306)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2305)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2304)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2303)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2302)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2301)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2300)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2299)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2298)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2297)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2296)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2295)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2294)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2293)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2292)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2291)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2290)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2289)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2288)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2287)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2286)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2285)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2284)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2283)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2282)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2281)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2280)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2279)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2278)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2277)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2276)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2275)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2274)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2273)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2272)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2271)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2270)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2269)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2268)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2267)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2266)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2265)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2264)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2263)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2262)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2261)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2260)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2259)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2258)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2257)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2256)
# End of values pass after 445 iterations
# 445  Obj 51.942401 Primal inf 3098.1598 (5540) Dual inf 5.5874233e+13 (2397) w.o. free dual inf (2256)
# Perturbing problem by 0.001% of 0.59241498 - largest nonzero change 0 ( 0%) - largesOPTIMAL
# FEASIBLE_POINTt zero change 2.9986437e-05
# 716  Obj 142.49186 Primal inf 1108.6486 (2761) Dual inf 6.3296667e+13 (2551) w.o. free dual inf (2501)
# 983  Obj 148.00893 Primal inf 849.06511 (2414) Dual inf 17548332 (2537) w.o. free dual inf (2493)
# 1250  Obj 157.91117 Primal inf 639.28496 (2055) Dual inf 15714452 (2531) w.o. free dual inf (2493)
# 1516  Obj 183.78384 Primal inf 462.63718 (1682) Dual inf 11922246 (2399) w.o. free dual inf (2364)
# 1780  Obj 195.86468 Primal inf 359.29105 (1330) Dual inf 11282757 (2246) w.o. free dual inf (2215)
# 2042  Obj 257.86948 Primal inf 230.65011 (948) Dual inf 8334478.1 (2232) w.o. free dual inf (2203)
# 2315  Obj 272.69347 Primal inf 160.38813 (720) Dual inf 7258249.3 (2150) w.o. free dual inf (2123)
# 2577  Obj 320.69045 Primal inf 94.700579 (479) Dual inf 6228102.3 (1945) w.o. free dual inf (1919)
# 2840  Obj 373.53372 Primal inf 34.440001 (248) Dual inf 5481803.6 (1825) w.o. free dual inf (1799)
# 3106  Obj 379.37596 Primal inf 9.9765027 (90) Dual inf 1939484.6 (1637) w.o. free dual inf (1612)
# 3372  Obj 383.44198 Primal inf 0.006791837 (1) Dual inf 42669.736 (1379) w.o. free dual inf (1356)
# 3633  Obj 365.83727 Dual inf 3227.3778 (1333)
# 3897  Obj 352.98319 Dual inf 6707.5333 (1392)
# 4109  Obj 346.4231 Dual inf 7094.7531 (1479)
# 4305  Obj 340.91353 Dual inf 5485.7889 (1191)
# 4567  Obj 331.48921 Dual inf 4608.686 (1233)
# 4773  Obj 326.35255 Dual inf 3693.4163 (1188)
# 5017  Obj 318.19947 Dual inf 11398.456 (1251)
# 5279  Obj 313.85038 Dual inf 4914.5243 (736)
# 5512  Obj 310.91398 Dual inf 498.01632 (542)
# 5759  Obj 308.6802 Dual inf 2837.3975 (794)
# 5993  Obj 307.61373 Dual inf 733.58986 (612)
# 6180  Obj 307.19688 Dual inf 184.28317 (164)
# 6313  Obj 307.1287
# Optimal - objective value 307.13401
# After Postsolve, objective 307.13401, infeasibilities - dual 4445.9542 (1313), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 307.13401 Dual inf 12.227395 (3)
# 15  Obj 307.13401
# Optimal - objective value 307.13401
# Optimal objective 307.1340139 - 6328 iterations time 7.322, Presolve 2.60
# 13094×50 SparseMatrixCSC{Float64, Int64} with 5473 stored entries:
# ⣦
# ⠿
# ⣪
# ⠋
# ⣿
# ⣐
# ⣐
# ⣛
# ⡿
# ⠛
# ⣾
# ⣿
# ⣿
# ⢿
# ⠂
# ⠀
# ⣿
# ⠙
# ⣚
# ⣿
# ⠲
# ⠀
# ⣿
# ⠬
# ⡿
# ⣉

# %%
# save the naive output
DelimitedFiles.writedlm("starting_v.txt", starting_v, ',')
DelimitedFiles.writedlm("starting_v_norm.txt", starting_v_norm, ',')

# %%
# solve with iterations to get a better answer compared to the naive l1 norm approach
delta = 0.0001
n = 1
num_iteration = 3
print(sparse(starting_v))
#prepare the model (in the for loop we only change the objective of the model)
model = JuMP.Model(Cbc.Optimizer)

@variable(model, v[1:size_of_v_r,1:size_of_v_c])  # define variable v
@variable(model, v_norm[1:size_of_v_r])  # define variable v_norm
@constraint(model, Matrix(L) .<= v .<= Matrix(U))  # l1 <= v <= u1
@constraint(model, Matrix(S) * v .== 0)  # Sv = 0

for i in 1:size_of_v_r
    for j in 1:size_of_v_c
        @constraint(model, v_norm[i] >= v[i,j])
        @constraint(model, v_norm[i] >= -v[i,j])
    end
end

#iterate
for iteration in 1:num_iteration
    print("doing iteration ")
    println(iteration)
    
    # decrement n
    n -= 0.5 / num_iteration
    
    w = zeros(size_of_v_r)
    for i in 1:size_of_v_r
        w[i] = delta ^ n / (delta ^ n + abs(starting_v_norm[i])^n)
    end
    
    # define the problem
    for i in 1:size_of_v_r
        for j in 1:size_of_v_c
            JuMP.set_start_value(v[i, j], starting_v[i, j])
        end
    end
    for i in 1:size_of_v_r
        JuMP.set_start_value(v_norm[i], starting_v_norm[i])
    end
    for i in 1:size_of_v_r
        if abs(starting_v_norm[i]) < 0.00002
            @constraint(model, v_norm[i] == starting_v_norm[i])
        end
    end
    @objective(model, Min, sum(v_norm[i] * w[i] for i in 1:size_of_v_r))  # min ||v||_1
    
    # solve the problem, check the status of it, and update starting_v and starting_v_norm
    optimize!(model)
    println(termination_status(model))
    println(primal_status(model))
    starting_v = JuMP.value.(v)
    starting_v_norm = JuMP.value.(v_norm)
    println("before saving")
    DelimitedFiles.writedlm(string(path, "output_iteration_", string(iteration), ".txt"), starting_v, ',')
    println("after saving")
end
sparse(starting_v)
# Out:
# ⣦
# ⣛
# ⣍
# ⠦
# ⣿
# ⡉
# ⠄
# ⠀
# ⠉
# ⡭
# ⣽
# ⣺
# ⣿
# ⣴
# ⠟
# ⣀
# ⠀
# ⠀
# ⣀
# ⣬
# ⠛
# ⣾
# ⣿
# ⣿
# ⣿
# ⣿doing iteration 1
# OPTIMAL
# FEASIBLE_POINT
# doing iteration 2
# Presolve 4237 (-735442) rows, 2873 (-203680) columns and 17309 (-1817910) elements
# Perturbing problem by 0.001% of 0.11181907 - largest nonzero change 0.00012545886 ( 43.254573%) - largest zero change 0.00012541338
# 0  Obj 0.16842677 Primal inf 882.2492 (2166)
# 159  Obj 0.17241145 Primal inf 756.01815 (2108)
# 318  Obj 0.17546503 Primal inf 674.97695 (2038)
# 477  Obj 0.18023367 Primal inf 570.76432 (1916)
# 636  Obj 0.18554139 Primal inf 561.72579 (1840)
# 795  Obj 0.18992477 Primal inf 409.30397 (1638)
# 954  Obj 0.19546722 Primal inf 308.41809 (1428)
# 1113  Obj 0.20091532 Primal inf 300.89234 (1284)
# 1272  Obj 0.20555672 Primal inf 220.59908 (1093)
# 1431  Obj 0.20920315 Primal inf 252.65073 (963)
# 1590  Obj 0.21576782 Primal inf 101.13983 (616)
# 1749  Obj 0.22084088 Primal inf 50.256922 (429)
# 1908  Obj 0.2272901 Primal inf 18.131517 (226)
# 2067  Obj 0.22917451 Primal inf 1.6048754 (73)
# 2141  Obj 0.22996682
# 2141  Obj 0.14185618 Dual inf 0.013011579 (76)
# 2269  Obj 0.14144284
# Optimal - objective value 0.14144284
# After Postsolve, objective 0.14144284, infeasibilities - dual 0.041416764 (47), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 0.14144284
# Optimal - objective value 0.14144284
# Optimal objective 0.1414428436 - 2269 iterations time 1.582, Presolve 0.93
# OPTIMAL
# FEASIBLE_POINT
# doing iteration 3
# Presolve 4237 (-741771) rows, 2873 (-203680) columns and 17309 (-1824239) elements
# Perturbing problem by 0.001% of 0.16005288 - largest nonzero change 0.00023265629 ( 15.464688%) - largest zero change 0.00023257195
# 0  Obj 0.57167454 Primal inf 882.2492 (2166)
# 159  Obj 0.57886819 Primal inf 754.69224 (2104)
# 318  Obj 0.58536669 Primal inf 684.94619 (2036)
# 477  Obj 0.59806305 Primal inf 570.13047 (1932)
# 636  Obj 0.61402141 Primal inf 700.49519 (1794)
# 795  Obj 0.6263367 Primal inf 690.48822 (1648)
# 954  Obj 0.64668153 Primal inf 268.65739 (1462)
# 1113  Obj 0.66439794 Primal inf 237.57303 (1286)
# 1272  Obj 0.67943601 Primal inf 182.08124 (1066)
# 1431  Obj 0.69637884 Primal inf 262.08775 (1024)
# 1590  Obj 0.71645939 Primal inf 122.46895 (735)
# 1749  Obj 0.7350777 Primal inf 384.89105 (755)
# 1908  Obj 0.76053363 Primal inf 23.935456 (292)
# 2067  Obj 0.76658283 Primal inf 46.189364 (186)
# 2184  Obj 0.76975804
# 2184  Obj 0.61198002 Dual inf 0.040109133 (63)
# 2244  Obj 0.61178191
# Optimal - objective value 0.61178191
# After Postsolve, objective 0.61178191, infeasibilities - dual 0.13024307 (43), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 0.61178191
# Optimal - objective value 0.61178191
# Optimal objective 0.6117819088 - 2244 iterations time 1.592, Presolve 0.95
# OPTIMAL
# FEASIBLE_POINT
# Presolve 4237 (-748100) rows, 2873 (-203680) columns and 17309 (-1830568) elements
# Perturbing problem by 0.001% of 0.22384889 - largest nonzero change 0.00080222268 ( 10.082254%) - largest zero change 0.00080097369
# 0  Obj 2.3566391 Primal inf 882.2492 (2166)
# 159  Obj 2.3765542 Primal inf 814.99598 (2112)
# 318  Obj 2.3970125 Primal inf 687.59327 (2034)
# 477  Obj 2.4456868 Primal inf 574.60413 (1946)
# 636  Obj 2.5107219 Primal inf 527.81456 (1819)
# 795  Obj 2.5594894 Primal inf 370.34127 (1625)
# 954  Obj 2.6526896 Primal inf 350.52693 (1513)
# 1113  Obj 2.713525 Primal inf 310.2181 (1372)
# 1272  Obj 2.787625 Primal inf 222.57671 (1158)
# 1431  Obj 2.843873 Primal inf 134.53845 (966)
# 1590  Obj 2.9278519 Primal inf 140.10718 (772)
# 1749  Obj 2.9914059 Primal inf 141.04205 (741)
# 1908  Obj 3.0730073 Primal inf 40.885304 (389)
# 2067  Obj 3.1063953 Primal inf 96.731473 (374)
# 2226  Obj 3.1210372 Primal inf 0.39990041 (37)
# 2266  Obj 3.122243
# 2266  Obj 2.6699496 Dual inf 0.018426687 (25)
# 2305  Obj 2.6696829
# Optimal - objective value 2.6696829
# After Postsolve, objective 2.6696829, infeasibilities - dual 0.51219629 (41), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 2.6696829
# Optimal - objective value 2.6696829
# Optimal objective 2.669682919 - 2305 iterations time 1.802, Presolve 1.07
# 6663×30 SparseMatrixCSC{Float64, Int64} with 3120 stored entries:
# ⣦
# ⣛
# ⣍
# ⠦
# ⣿
# ⡉
# ⠄
# ⠀
# ⠉
# ⡭
# ⣽
# ⣺
# ⣿
# ⣴
# ⠟
# ⣀
# ⠀
# ⠀
# ⣀
# ⣬
# ⠛
# ⣾
# ⣿
# ⣿
# ⣿
# ⣿

# %%
# save the stronger output
DelimitedFiles.writedlm("output.txt", starting_v, ',')

# %%
# compute the bounds of l1 norm of x_i (MN stands for maximum norm)
MN = zeros(size_of_v_r)
for i in 1:size_of_v_r
    for j in 1:size_of_v_c
        MN[i] = max(abs(L[i, j]), abs(U[i, j]), MN[i])
    end
end
MN
# Out:
# 13094-element Vector{Float64}:
#  2.1690399722928957
#  0.7979818884299401
#  0.6034452341648391
#  1.049327387497892
#  1.722843680651103
#  1.0140993341899616
#  1.8921080897429328
#  1.7834989549225733
#  2.3186282587190174e-14
#  2.2318574437653336
#  0.887552481271632
#  1.6339781474797015
#  1.0021247830845401
#  ⋮
#  1.033591828000263
#  8.000698154712564e-17
#  2.0879247458562884
#  0.8634368719891129
#  1.8542278194565551
#  1.7014803208455713
#  1.0966976192345625
#  0.7498155575470894
#  1.2284105736717526e-15
#  0.0
#  2.303184195420016
#  1.5479699019445032

# %%
# now solve the exact problem using MILP and with the starting points from previous part

# define the problem (we use Cbc because GLPK wrapper in JuMP doesnt support starting points)
model = JuMP.Model(Cbc.Optimizer)
@variable(model, v[1:size_of_v_r, 1:size_of_v_c])  # define variable v
for i in 1:size_of_v_r
    for j in 1:size_of_v_c
        JuMP.set_start_value(v[i, j], starting_v[i, j])
    end
end
@variable(model, v_norm[1:size_of_v_r])
for i in 1:size_of_v_r
    JuMP.set_start_value(v_norm[i], starting_v_norm[i])
end
@variable(model, b[1:size_of_v_r])
println("variables built")
@constraint(model, Matrix(L) .<= v .<= Matrix(U))  # l <= v <= u
@constraint(model, Matrix(S) * v .== 0)  # Sv = 0

@objective(model, Min, sum(b[i] for i in 1:size_of_v_r))  # min ||v||_0

for i in 1:size_of_v_r
    for j in 1:size_of_v_c
        @constraint(model, v_norm[i] >= v[i, j])
        @constraint(model, v_norm[i] >= -v[i, j])
    end
end
for i in 1:size_of_v_r
    @constraint(model, -MN[i] * b[i] <= v_norm[i])
    @constraint(model, v_norm[i] <= MN[i]*b[i])
    @constraint(model, b[i] in MathOptInterface.ZeroOne())
end
println("model created")

# solve the problem, print its status, and store the results
optimize!(model)
println(termination_status(model))
println(primal_status(model))
starting_v = JuMP.value.(v)
# Out:
# what is happening :/
# haha0!
# variable 1
# variables built
# haha3
# haha1
# haha2
# model created

# %%
# save the final (exact) answer
DelimitedFiles.writedlm("output.txt", starting_v, ',')
# Out:
# UndefVarError: DelimitedFiles not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[1]:2
#  [2] eval
#    @ .\boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1094
